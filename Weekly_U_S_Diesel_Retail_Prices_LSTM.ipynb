# %%
# ==============================================================================
#
# TIME SERIES QUESTION
#
# Build and train a neural network to predict the time indexed variable of
# the univariate US diesel prices (On - Highway) All types for the period of
# 1994 - 2021.
# Using a window of past 10 observations of 1 feature , train the model
# to predict the next 10 observations of that feature.
#
# ==============================================================================
#
# ABOUT THE DATASET
#
# Original Source:
# https://www.eia.gov/dnav/pet/pet_pri_gnd_dcus_nus_w.htm#
#
# For the purpose of the examination we have used the Diesel (On - Highway) -
# All Types time series data for the period of 1994 - 2021 from the
# aforementioned link. The dataset has 1 time indexed feature.
# We have provided a cleaned version of the data.
#
# ==============================================================================


import pandas as pd
import tensorflow as tf
import urllib

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

url = 'https://www.dropbox.com/s/eduk281didil1km/Weekly_U.S.Diesel_Retail_Prices.csv?dl=1'
urllib.request.urlretrieve(url, 'Weekly_U.S.Diesel_Retail_Prices.csv')

# This function normalizes the dataset using min max scaling.
# DO NOT CHANGE THIS CODE
def normalize_series(data, min, max):
    data = data - min
    data = data / max
    return data

def windowed_dataset(series, batch_size, n_past=10, n_future=10, shift=1):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(size=n_past + n_future, shift=shift, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(n_past + n_future))
    ds = ds.map(lambda w: (w[:n_past], w[n_past:]))
    return ds.batch(batch_size).prefetch(1)

def solution_model():
    # DO NOT CHANGE THIS CODE
    # Reads the dataset.
    df = pd.read_csv('Weekly_U.S.Diesel_Retail_Prices.csv',
                     infer_datetime_format=True, index_col='Week of', header=0)

    df.head(20)

    # Number of features in the dataset. We use all features as predictors to
    # predict all features of future time steps.
    N_FEATURES = len(df.columns)

    # Normalizes the data
    data = df.values
    data = normalize_series(data, data.min(axis=0), data.max(axis=0))

    # Splits the data into training and validation sets.
    SPLIT_TIME = int(len(data) * 0.8)
    x_train = data[:SPLIT_TIME]
    x_valid = data[SPLIT_TIME:]

    tf.keras.backend.clear_session()
    tf.random.set_seed(42)

    BATCH_SIZE = 32  # ADVISED NOT TO CHANGE THIS

    N_PAST = 10  # DO NOT CHANGE THIS

    N_FUTURE = 10  # DO NOT CHANGE THIS

    SHIFT = 1  # DO NOT CHANGE THIS

    train_set = windowed_dataset(series=x_train, batch_size=BATCH_SIZE,
                                 n_past=N_PAST, n_future=N_FUTURE,
                                 shift=SHIFT)
    valid_set = windowed_dataset(series=x_valid, batch_size=BATCH_SIZE,
                                 n_past=N_PAST, n_future=N_FUTURE,
                                 shift=SHIFT)

    # Code to define your model.
    model = tf.keras.models.Sequential([

        Conv1D(filters=32, kernel_size=5, padding='causal', activation='relu', input_shape=[N_PAST, 1]),
        Bidirectional(LSTM(32, return_sequences=True)),
        Bidirectional(LSTM(32, return_sequences=True)),
        Dense(32, activation='relu'),
        Dense(16, activation='relu'),

        tf.keras.layers.Dense(N_FEATURES)
    ])

    # 체크포인트 생성
    checkpoint_path = 'model/my_checkpoint.ckpt'
    checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                                 save_weights_only=True,
                                 save_best_only=True,
                                 monitor='val_mae',
                                 verbose=1)

    # Code to train and compile the model
    optimizer = tf.keras.optimizers.Adam(0.0001)
    model.compile(
        optimizer=optimizer, loss=tf.keras.losses.Huber(), metrics=['mae']
    )
    model.fit(
        train_set,
        validation_data=(valid_set),
        epochs=100,
        callbacks=[checkpoint]
    )

    model.load_weights(checkpoint_path)

    return model

if __name__ == '__main__':
    model = solution_model()
    model.save("model.h5")
# Out:
# Epoch 1/100
# 35/35 [==============================] - 35s 55ms/step - loss: 0.0531 - mae: 0.2528 - val_loss: 0.0549 - val_mae: 0.3253
#
# Epoch 00001: val_mae improved from inf to 0.32533, saving model to model/my_checkpoint.ckpt
# Epoch 2/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0375 - mae: 0.2019 - val_loss: 0.0347 - val_mae: 0.2563
#
# Epoch 00002: val_mae improved from 0.32533 to 0.25625, saving model to model/my_checkpoint.ckpt
# Epoch 3/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0211 - mae: 0.1501 - val_loss: 0.0138 - val_mae: 0.1557
#
# Epoch 00003: val_mae improved from 0.25625 to 0.15567, saving model to model/my_checkpoint.ckpt
# Epoch 4/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0084 - mae: 0.1049 - val_loss: 0.0025 - val_mae: 0.0565
#
# Epoch 00004: val_mae improved from 0.15567 to 0.05648, saving model to model/my_checkpoint.ckpt
# Epoch 5/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0055 - mae: 0.0908 - val_loss: 0.0013 - val_mae: 0.0412
#
# Epoch 00005: val_mae improved from 0.05648 to 0.04121, saving model to model/my_checkpoint.ckpt
# Epoch 6/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0048 - mae: 0.0845 - val_loss: 0.0012 - val_mae: 0.0387
#
# Epoch 00006: val_mae improved from 0.04121 to 0.03871, saving model to model/my_checkpoint.ckpt
# Epoch 7/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0036 - mae: 0.0724 - val_loss: 0.0010 - val_mae: 0.0353
#
# Epoch 00007: val_mae improved from 0.03871 to 0.03530, saving model to model/my_checkpoint.ckpt
# Epoch 8/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0027 - mae: 0.0604 - val_loss: 9.3465e-04 - val_mae: 0.0328
#
# Epoch 00008: val_mae improved from 0.03530 to 0.03278, saving model to model/my_checkpoint.ckpt
# Epoch 9/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0021 - mae: 0.0512 - val_loss: 8.6435e-04 - val_mae: 0.0310
#
# Epoch 00009: val_mae improved from 0.03278 to 0.03104, saving model to model/my_checkpoint.ckpt
# Epoch 10/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0018 - mae: 0.0440 - val_loss: 8.2877e-04 - val_mae: 0.0302
#
# Epoch 00010: val_mae improved from 0.03104 to 0.03017, saving model to model/my_checkpoint.ckpt
# Epoch 11/100
# 35/35 [==============================] - 1s 19ms/step - loss: 0.0016 - mae: 0.0394 - val_loss: 7.9971e-04 - val_mae: 0.0294
#
# Epoch 00011: val_mae improved from 0.03017 to 0.02939, saving model to model/my_checkpoint.ckpt
# Epoch 12/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0015 - mae: 0.0365 - val_loss: 7.7166e-04 - val_mae: 0.0287
#
# Epoch 00012: val_mae improved from 0.02939 to 0.02870, saving model to model/my_checkpoint.ckpt
# Epoch 13/100
# 35/35 [==============================] - 1s 19ms/step - loss: 0.0015 - mae: 0.0347 - val_loss: 7.4818e-04 - val_mae: 0.0282
#
# Epoch 00013: val_mae improved from 0.02870 to 0.02817, saving model to model/my_checkpoint.ckpt
# Epoch 14/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0014 - mae: 0.0341 - val_loss: 7.4273e-04 - val_mae: 0.0281
#
# Epoch 00014: val_mae improved from 0.02817 to 0.02808, saving model to model/my_checkpoint.ckpt
# Epoch 15/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0014 - mae: 0.0335 - val_loss: 7.3429e-04 - val_mae: 0.0279
#
# Epoch 00015: val_mae improved from 0.02808 to 0.02790, saving model to model/my_checkpoint.ckpt
# Epoch 16/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0014 - mae: 0.0330 - val_loss: 7.3116e-04 - val_mae: 0.0279
#
# Epoch 00016: val_mae improved from 0.02790 to 0.02787, saving model to model/my_checkpoint.ckpt
# Epoch 17/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0014 - mae: 0.0327 - val_loss: 7.2786e-04 - val_mae: 0.0278
#
# Epoch 00017: val_mae improved from 0.02787 to 0.02785, saving model to model/my_checkpoint.ckpt
# Epoch 18/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0014 - mae: 0.0326 - val_loss: 7.2937e-04 - val_mae: 0.0279
#
# Epoch 00018: val_mae did not improve from 0.02785
# Epoch 19/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0014 - mae: 0.0323 - val_loss: 7.2564e-04 - val_mae: 0.0279
#
# Epoch 00019: val_mae did not improve from 0.02785
# Epoch 20/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0014 - mae: 0.0322 - val_loss: 7.2834e-04 - val_mae: 0.0280
#
# Epoch 00020: val_mae did not improve from 0.02785
# Epoch 21/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0321 - val_loss: 7.2672e-04 - val_mae: 0.0280
#
# Epoch 00021: val_mae did not improve from 0.02785
# Epoch 22/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0320 - val_loss: 7.2864e-04 - val_mae: 0.0281
#
# Epoch 00022: val_mae did not improve from 0.02785
# Epoch 23/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0319 - val_loss: 7.2840e-04 - val_mae: 0.0281
#
# Epoch 00023: val_mae did not improve from 0.02785
# Epoch 24/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0319 - val_loss: 7.3096e-04 - val_mae: 0.0282
#
# Epoch 00024: val_mae did not improve from 0.02785
# Epoch 25/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0318 - val_loss: 7.3002e-04 - val_mae: 0.0282
#
# Epoch 00025: val_mae did not improve from 0.02785
# Epoch 26/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0318 - val_loss: 7.3288e-04 - val_mae: 0.0283
#
# Epoch 00026: val_mae did not improve from 0.02785
# Epoch 27/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0317 - val_loss: 7.3283e-04 - val_mae: 0.0283
#
# Epoch 00027: val_mae did not improve from 0.02785
# Epoch 28/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0317 - val_loss: 7.3474e-04 - val_mae: 0.0284
#
# Epoch 00028: val_mae did not improve from 0.02785
# Epoch 29/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0316 - val_loss: 7.3423e-04 - val_mae: 0.0284
#
# Epoch 00029: val_mae did not improve from 0.02785
# Epoch 30/100
# 35/35 [==============================] - 1s 19ms/step - loss: 0.0013 - mae: 0.0316 - val_loss: 7.3661e-04 - val_mae: 0.0285
#
# Epoch 00030: val_mae did not improve from 0.02785
# Epoch 31/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0315 - val_loss: 7.3693e-04 - val_mae: 0.0285
#
# Epoch 00031: val_mae did not improve from 0.02785
# Epoch 32/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0315 - val_loss: 7.3855e-04 - val_mae: 0.0286
#
# Epoch 00032: val_mae did not improve from 0.02785
# Epoch 33/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.3768e-04 - val_mae: 0.0286
#
# Epoch 00033: val_mae did not improve from 0.02785
# Epoch 34/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.4136e-04 - val_mae: 0.0287
#
# Epoch 00034: val_mae did not improve from 0.02785
# Epoch 35/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.4035e-04 - val_mae: 0.0287
#
# Epoch 00035: val_mae did not improve from 0.02785
# Epoch 36/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0314 - val_loss: 7.4232e-04 - val_mae: 0.0287
#
# Epoch 00036: val_mae did not improve from 0.02785
# Epoch 37/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0313 - val_loss: 7.4157e-04 - val_mae: 0.0287
#
# Epoch 00037: val_mae did not improve from 0.02785
# Epoch 38/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0313 - val_loss: 7.4452e-04 - val_mae: 0.0288
#
# Epoch 00038: val_mae did not improve from 0.02785
# Epoch 39/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.4235e-04 - val_mae: 0.0288
#
# Epoch 00039: val_mae did not improve from 0.02785
# Epoch 40/100
# 35/35 [==============================] - 1s 19ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.4830e-04 - val_mae: 0.0289
#
# Epoch 00040: val_mae did not improve from 0.02785
# Epoch 41/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.4465e-04 - val_mae: 0.0289
#
# Epoch 00041: val_mae did not improve from 0.02785
# Epoch 42/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0312 - val_loss: 7.4692e-04 - val_mae: 0.0289
#
# Epoch 00042: val_mae did not improve from 0.02785
# Epoch 43/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.4586e-04 - val_mae: 0.0289
#
# Epoch 00043: val_mae did not improve from 0.02785
# Epoch 44/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.4795e-04 - val_mae: 0.0290
#
# Epoch 00044: val_mae did not improve from 0.02785
# Epoch 45/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.4546e-04 - val_mae: 0.0289
#
# Epoch 00045: val_mae did not improve from 0.02785
# Epoch 46/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0311 - val_loss: 7.4858e-04 - val_mae: 0.0290
#
# Epoch 00046: val_mae did not improve from 0.02785
# Epoch 47/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0310 - val_loss: 7.4621e-04 - val_mae: 0.0290
#
# Epoch 00047: val_mae did not improve from 0.02785
# Epoch 48/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0310 - val_loss: 7.4910e-04 - val_mae: 0.0290
#
# Epoch 00048: val_mae did not improve from 0.02785
# Epoch 49/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0310 - val_loss: 7.4723e-04 - val_mae: 0.0290
#
# Epoch 00049: val_mae did not improve from 0.02785
# Epoch 50/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0310 - val_loss: 7.5094e-04 - val_mae: 0.0291
#
# Epoch 00050: val_mae did not improve from 0.02785
# Epoch 51/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0309 - val_loss: 7.4805e-04 - val_mae: 0.0290
#
# Epoch 00051: val_mae did not improve from 0.02785
# Epoch 52/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0309 - val_loss: 7.4965e-04 - val_mae: 0.0291
#
# Epoch 00052: val_mae did not improve from 0.02785
# Epoch 53/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0309 - val_loss: 7.4840e-04 - val_mae: 0.0291
#
# Epoch 00053: val_mae did not improve from 0.02785
# Epoch 54/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0309 - val_loss: 7.5050e-04 - val_mae: 0.0291
#
# Epoch 00054: val_mae did not improve from 0.02785
# Epoch 55/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0308 - val_loss: 7.4983e-04 - val_mae: 0.0291
#
# Epoch 00055: val_mae did not improve from 0.02785
# Epoch 56/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0308 - val_loss: 7.5204e-04 - val_mae: 0.0292
#
# Epoch 00056: val_mae did not improve from 0.02785
# Epoch 57/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0308 - val_loss: 7.5237e-04 - val_mae: 0.0292
#
# Epoch 00057: val_mae did not improve from 0.02785
# Epoch 58/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0308 - val_loss: 7.5332e-04 - val_mae: 0.0292
#
# Epoch 00058: val_mae did not improve from 0.02785
# Epoch 59/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0308 - val_loss: 7.5732e-04 - val_mae: 0.0293
#
# Epoch 00059: val_mae did not improve from 0.02785
# Epoch 60/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0308 - val_loss: 7.5914e-04 - val_mae: 0.0294
#
# Epoch 00060: val_mae did not improve from 0.02785
# Epoch 61/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0307 - val_loss: 7.6212e-04 - val_mae: 0.0295
#
# Epoch 00061: val_mae did not improve from 0.02785
# Epoch 62/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0307 - val_loss: 7.6318e-04 - val_mae: 0.0295
#
# Epoch 00062: val_mae did not improve from 0.02785
# Epoch 63/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0307 - val_loss: 7.6635e-04 - val_mae: 0.0297
#
# Epoch 00063: val_mae did not improve from 0.02785
# Epoch 64/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0307 - val_loss: 7.7325e-04 - val_mae: 0.0299
#
# Epoch 00064: val_mae did not improve from 0.02785
# Epoch 65/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0307 - val_loss: 7.7778e-04 - val_mae: 0.0300
#
# Epoch 00065: val_mae did not improve from 0.02785
# Epoch 66/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0307 - val_loss: 7.7984e-04 - val_mae: 0.0301
#
# Epoch 00066: val_mae did not improve from 0.02785
# Epoch 67/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0307 - val_loss: 7.8503e-04 - val_mae: 0.0302
#
# Epoch 00067: val_mae did not improve from 0.02785
# Epoch 68/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0307 - val_loss: 7.9470e-04 - val_mae: 0.0305
#
# Epoch 00068: val_mae did not improve from 0.02785
# Epoch 69/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0308 - val_loss: 8.0330e-04 - val_mae: 0.0307
#
# Epoch 00069: val_mae did not improve from 0.02785
# Epoch 70/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0307 - val_loss: 8.0875e-04 - val_mae: 0.0309
#
# Epoch 00070: val_mae did not improve from 0.02785
# Epoch 71/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0307 - val_loss: 8.1787e-04 - val_mae: 0.0311
#
# Epoch 00071: val_mae did not improve from 0.02785
# Epoch 72/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0306 - val_loss: 8.0582e-04 - val_mae: 0.0309
#
# Epoch 00072: val_mae did not improve from 0.02785
# Epoch 73/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0305 - val_loss: 8.2121e-04 - val_mae: 0.0312
#
# Epoch 00073: val_mae did not improve from 0.02785
# Epoch 74/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0304 - val_loss: 7.9999e-04 - val_mae: 0.0307
#
# Epoch 00074: val_mae did not improve from 0.02785
# Epoch 75/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0304 - val_loss: 8.1785e-04 - val_mae: 0.0311
#
# Epoch 00075: val_mae did not improve from 0.02785
# Epoch 76/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0304 - val_loss: 8.1306e-04 - val_mae: 0.0311
#
# Epoch 00076: val_mae did not improve from 0.02785
# Epoch 77/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0304 - val_loss: 8.2374e-04 - val_mae: 0.0313
#
# Epoch 00077: val_mae did not improve from 0.02785
# Epoch 78/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0304 - val_loss: 8.1621e-04 - val_mae: 0.0312
#
# Epoch 00078: val_mae did not improve from 0.02785
# Epoch 79/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0304 - val_loss: 8.2566e-04 - val_mae: 0.0314
#
# Epoch 00079: val_mae did not improve from 0.02785
# Epoch 80/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0303 - val_loss: 8.2244e-04 - val_mae: 0.0313
#
# Epoch 00080: val_mae did not improve from 0.02785
# Epoch 81/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0303 - val_loss: 8.2731e-04 - val_mae: 0.0314
#
# Epoch 00081: val_mae did not improve from 0.02785
# Epoch 82/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0302 - val_loss: 8.2773e-04 - val_mae: 0.0315
#
# Epoch 00082: val_mae did not improve from 0.02785
# Epoch 83/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0302 - val_loss: 8.2658e-04 - val_mae: 0.0314
#
# Epoch 00083: val_mae did not improve from 0.02785
# Epoch 84/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0301 - val_loss: 8.2403e-04 - val_mae: 0.0314
#
# Epoch 00084: val_mae did not improve from 0.02785
# Epoch 85/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0301 - val_loss: 8.2520e-04 - val_mae: 0.0314
#
# Epoch 00085: val_mae did not improve from 0.02785
# Epoch 86/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0301 - val_loss: 8.2454e-04 - val_mae: 0.0314
#
# Epoch 00086: val_mae did not improve from 0.02785
# Epoch 87/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0300 - val_loss: 8.2451e-04 - val_mae: 0.0314
#
# Epoch 00087: val_mae did not improve from 0.02785
# Epoch 88/100
# 35/35 [==============================] - 1s 19ms/step - loss: 0.0012 - mae: 0.0300 - val_loss: 8.2640e-04 - val_mae: 0.0315
#
# Epoch 00088: val_mae did not improve from 0.02785
# Epoch 89/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0300 - val_loss: 8.2627e-04 - val_mae: 0.0315
#
# Epoch 00089: val_mae did not improve from 0.02785
# Epoch 90/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0300 - val_loss: 8.2835e-04 - val_mae: 0.0316
#
# Epoch 00090: val_mae did not improve from 0.02785
# Epoch 91/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0299 - val_loss: 8.2852e-04 - val_mae: 0.0316
#
# Epoch 00091: val_mae did not improve from 0.02785
# Epoch 92/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0299 - val_loss: 8.3248e-04 - val_mae: 0.0317
#
# Epoch 00092: val_mae did not improve from 0.02785
# Epoch 93/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0299 - val_loss: 8.3366e-04 - val_mae: 0.0317
#
# Epoch 00093: val_mae did not improve from 0.02785
# Epoch 94/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0299 - val_loss: 8.4036e-04 - val_mae: 0.0319
#
# Epoch 00094: val_mae did not improve from 0.02785
# Epoch 95/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0011 - mae: 0.0298 - val_loss: 8.4145e-04 - val_mae: 0.0319
#
# Epoch 00095: val_mae did not improve from 0.02785
# Epoch 96/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0011 - mae: 0.0298 - val_loss: 8.4326e-04 - val_mae: 0.0320
#
# Epoch 00096: val_mae did not improve from 0.02785
# Epoch 97/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0011 - mae: 0.0298 - val_loss: 8.4514e-04 - val_mae: 0.0320
#
# Epoch 00097: val_mae did not improve from 0.02785
# Epoch 98/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0011 - mae: 0.0297 - val_loss: 8.4826e-04 - val_mae: 0.0321
#
# Epoch 00098: val_mae did not improve from 0.02785
# Epoch 99/100
# 35/35 [==============================] - 1s 21ms/step - loss: 0.0011 - mae: 0.0297 - val_loss: 8.5235e-04 - val_mae: 0.0323
#
# Epoch 00099: val_mae did not improve from 0.02785
# Epoch 100/100
# 35/35 [==============================] - 1s 20ms/step - loss: 0.0011 - mae: 0.0297 - val_loss: 8.5576e-04 - val_mae: 0.0323
#
# Epoch 00100: val_mae did not improve from 0.02785
